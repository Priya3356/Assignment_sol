# %% [markdown]
# # If - elif - else statement

# %%
#W. A P. which takes one number from 0 to 9 from the user and prints it in the word. And if the word is not from 0 to 9 then
#it should print that number is outside of the range and program should exit.
# For exapmple:- 
# input = 1
# output = one

num = int(input('Enter a number: '))
if num == 0:
  print('Zero')
elif num ==1:
  print('One')
elif num ==2:
  print('Two')
elif num ==4:
  print('Four')
elif num ==5:
  print('Five')
elif num ==6:
  print('Six')
elif num ==7:
  print('Seven')
elif num ==8:
  print('Eight')
elif num ==9:
  print('Nine')
else:
  print('Number is outside the range!!!')
# Out:
# Enter a number: 1
# One

# %%
#W. A P. to implement calculator but the operation to be done and two numbers will be taken as input from user:-
#Operation console should show below:-
#     Please select any one operation from below:-
#         * To add enter 1
#         * to subtract enter 2
#         * To multiply enter 3
#         * To divide enter 4
#         * To divide and find quotient enter 5
#         * To divide and find remainder enter 6
#         * To divide and find num1 to the power of num2 enter 7
#         * To Come out of the program enter 8

a = int(input("Enter your choice:"))     # a = [1,2,3,4,5,6,7,8]
if a>=1 and a<=8:
    print("Enter two numbers:")
num1 = int(input())
num2 = int(input())

if a==1:  # to add two numbers
    res = num1 + num2
    print("Result = ", res)
    
elif a==2:  # to subtract two numbers
    res = num1 - num2
    print("Result = ", res)

elif a==3:  # to multiply two numbers
    res = num1 * num2
    print("Result = ", res)
    
elif a==4:  # to divide two numbers
    res = num1 / num2
    print("Result = ", res)

elif a==5:  # quotient
    res = num1 % num2
    print("Result = ", res)

elif a==6:  # to reminder
    res = num1 // num2
    print("Result = ", res)
    
elif a==7:  # to power
    res = num1 ** num2
    print("Result = ", res)
    
elif a==8:  # exit
    res = exit()

else:
    print("wrong output")
# Out:
# Enter your choice:4
# Enter two numbers:
# 4
# 2
# Result =  2.0

# %%
#W A P to check whether a year entered by user is an leap year or not?
#Check with below input:-
    #leap year:- 2012, 1968, 2004, 1200, 1600,2400
    #Non-lear year:- 1971, 2006, 1700,1800,1900

    
year = int(input('Enter a year (YYYY): '))
if (year % 4) == 0:
    if (year % 100) == 0:
        if (year % 400) == 0:
            print("{0} is a leap year".format(year))
        else:
             print("{0} is not a leap year".format(year))
    else:
        print("{0} is a leap year".format(year))
else:
    print("{0} is not a leap year".format(year))
# Out:
# Enter a year (YYYY): 2012
# 2012 is a leap year

# %%
#W A P which takes one number from the user and checks whether it is an even or odd number?, If it even then prints number is 
#even number else prints that number is odd number.
num = int(input("Enter an integer: "))
if num%2 == 0:
 print('{} is an even number.'.format(num))
else:
 print('{} is an odd number.'.format(num))
# Out:
# Enter an integer: 5
# 5 is an odd number.

# %%
#W A P which takes two numbers from the user and prints below output:-
#     1. num1 is greater than num2 if num1 is greater than num2
#     2. num1 is smaller than num2 if num1 is smaller than num2
#     3. num1 is equal to num2 if num1 and num2 are equal

#Note:- 1. Do this problem using if - else 
#       2. Do this using ternary operator
# 1.
n1 = int(input('Enter first number: '))
n2 = int(input('Enter second number: '))
if n1 > n2 :
    print("{} is greater than {}".format(n1,n2))
elif n1 < n2:
    print("{} is greater than {}".format(n2,n1))
else:
    print("{} is equal to {}".format(n1,n2))
# Out:
# Enter first number: 4
# Enter second number: 4
# 4 is equal to 4

# %%
#W A P which takes three numbers from the user and prints below output:-
#     1. num1 is greater than num2 and num3 if num1 is greater than num2 and num3
#     2. num2 is greater than num1 and num3 if num2 is greater than num1 and num3
#     3. num3 is greater than num1 and num2 if num3 is greater than num1 and num2

#Note:- 1. Do this problem using if - elif - else 
#       2. Do this using ternary operator

# a = a if a>b else b
num1 = int(input('Enter the first No.: '))
num2 = int(input('Enter the Second No.: '))
num3 = int(input('Enter the Third No.: '))
if ((num1>= num2) and (num1>= num3)) or ((num2<= num1) and (num2<= num3)):
    print(f'The Maximum no is {num1}')
    print(f'The Minimum no is {num2}')
elif ((num3>= num1) and (num3>= num2)) or ((num1<= num2) and (num1<= num3)):   
    print(f'The Maximum no is {num3}') 
    print(f'The Minimum no is {num1}')
else:   
    print(f'The Maximum no is {num2}')  
    print(f'The Minimum no is {num3}')
# Out:
# Enter the first No.: 6
# Enter the Second No.: 2
# Enter the Third No.: 1
# The Maximum no is 6
# The Minimum no is 2

# %% [markdown]
# # Loops - for loop, while loop

# %%
#Write a Python program to find the length of the my_str using loop:-

#Input:- 'Write a Python program to find the length of the my_str'
#Output:- 55
my_str = 'Write a Python program to find the length of the my_str'
counter = 0
for i in my_str:
      counter = counter+1
print("Length of a string is:", counter)
# Out:
# Length of a string is: 55

# %%
#Write a Python program to find the total number of times letter 'p' is appeared in the below string using loop:-    
#Input:- 'peter piper picked a peck of pickled peppers.\n'
#Output:- 9
my_str = 'peter piper picked a peck of pickled peppers.\n' 
print(my_str.count('p'))
counter = 0
for char in my_str:
    if char == 'p':
        counter = counter+1
print("count of 'p' in a string:", counter)
# Out:
# 9
# count of 'p' in a string: 9

# %%
#Write a Python Program, to print all the indexes of all occurences of letter 'p' appeared in the string using loop:-
    
#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

my_str = 'peter piper picked a peck of pickled peppers.'
i = 0
while i<len(my_str):
    if my_str[i] == 'p':
        print(i)
    i +=1
# Out:
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']

i = 0
from_index = 0
str_list = []
while i < len(my_str):
    if my_str[i] == ' ':
        curr_index = i
        str_list.append(my_str[from_index:curr_index])
        from_index = i+1 
    elif i == len(my_str) -1:
        str_list.append(my_str[from_index:])
    i +=1
print(str_list)
# Out:
# ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers.']

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'peppers pickled of peck a picked piper peter'

def my_split(str1):
    out_str=''
    res_str=''
    for i in range(len(str1)-1,-1,-1):
        if str1[i] == ' ':
            res_str = res_str + out_str + ' '
            out_str = ''
        elif i == 0:
            out_str = str1[i] + out_str
            res_str = res_str + out_str
        else:
            out_str = str1[i] + out_str
    return res_str
my_split(my_str)
# Out:
# 'peppers. pickled of peck a picked piper peter'

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- '.sreppep delkcip fo kcep a dekcip repip retep'
my_str = 'peter piper picked a peck of pickled peppers.'
print('Input:- {}'.format(my_str))
i = len(my_str) - 1
new_str = ''
while i >= 0:
    new_str = new_str + my_str[i]
    i = i -1
print(' Output:- {}'.format(new_str))
# Out:
# Input:- peter piper picked a peck of pickled peppers.
#  Output:- .sreppep delkcip fo kcep a dekcip repip retep

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'retep repip dekcip a kcep fo delkcip sreppep'

my_str = 'peter piper picked a peck of pickled peppers.'
print('Input:- {}'.format(my_str))
my_str = my_str[:len(my_str) -1] 
## using loop
i = 0
from_indx = 0
new_str = ''
while i < len(my_str):
    if my_str[i] == ' ':
        curr_indx = i
        new_str = new_str + my_str[from_indx:curr_indx][::-1] + ' '
        from_indx = i+1
    elif i == len(my_str) - 1:
        new_str = new_str + my_str[from_indx:i+1][::-1]
    i += 1
print('Output:- {}'.format(new_str))
# Out:
# Input:- peter piper picked a peck of pickled peppers.
# Output:- retep repip dekcip a kcep fo delkcip sreppep

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'Peter Piper Picked A Peck Of Pickled Peppers'

my_str = 'peter piper picked a peck of pickled peppers.'
print('Input:- {}'.format(my_str))
## using loop
i = 0
from_indx = 0
new_str = ''
while i < len(my_str):
    if my_str[i] == ' ':
        curr_indx = i
        new_str = new_str + my_str[from_indx].upper() + my_str[from_indx + 1:curr_indx] + ' '
        from_indx = i+1
    elif i == len(my_str) - 1:
        new_str = new_str + my_str[from_indx].upper() +my_str[from_indx + 1:i+1]
    i += 1
print('Output:- {}'.format(new_str))
# Out:
# Input:- peter piper picked a peck of pickled peppers.
# Output:- Peter Piper Picked A Peck Of Pickled Peppers.

# %%
#Write a python program to find below output using loop:-

#Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.'
#Output:- 'Peter piper picked a peck of pickled peppers'

mystr = 'Peter Piper Picked A Peck Of Pickled Peppers.'
print('Input:- {}'.format(mystr))
## using loop
i = 0
newstr = ''
from_indx = 0
while i < len(mystr):
    if mystr[i] == ' ':
        newstr = newstr + mystr[from_indx].upper() + mystr[from_indx + 1: ]
        break
    i += 1
print('Output:- {}'.format(newstr))
# Out:
# Input:- Peter Piper Picked A Peck Of Pickled Peppers.
# Output:- Peter Piper Picked A Peck Of Pickled Peppers.

# %%
#Write a python program to implement index method using loop. If sub_str is found in my_str then it will print the index
# of first occurrence of first character of matching string in my_str:-

#Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Pickl'
#Output:- 29
my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Pickl'
new_str = ''
j = 0
for i in range(len(my_str)):
    if my_str[i] == sub_str[j]:
        new_str += my_str[i]
        j += 1
        if new_str == sub_str:
            print(i-len(sub_str)+1)
            break
    elif i == len(my_str)-1:
        print('Not found')
    else:
        new_str = ''
        j = 0
# Out:
# 29

# %%
#Write a python program to implement replace method using loop. If sub_str is found in my_str then it will replace the first 
#occurrence of sub_str with new_str else it will will print sub_str not found:-

#Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck', new_str = 'Pack'
#Output:- 'Peter Piper Picked A Pack Of Pickled Peppers.'

my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'
new_str1 = 'Pack'
out_str = ''
j = 0
new_str = ''
for i in range(len(my_str)):
    if my_str[i] == sub_str[j]:
        new_str += my_str[i]
        j += 1
        if len(new_str) == len(sub_str) and new_str == sub_str:
            ind = i-(len(sub_str)-1)
            print(ind)
            out_str = my_str[:ind] + new_str1 + my_str[ind+(len(sub_str)):]
            print(out_str)
            break
        elif len(new_str) == len(sub_str) and new_str != sub_str:
            new_str = ''
    elif i == (len(my_str)-1):
        print('string not found!')
    else:
        new_str = ''
        j = 0
# Out:
# 21
# Peter Piper Picked A Pack Of Pickled Peppers.

# %%
#Write a python program to find below output (implements rjust and ljust) using loop:-

#Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck', 
#Output:- '*********************Peck********************'

my_str='Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str='Peck'
out_str=''
i=0
while i in range(0,len(my_str),1):
    if my_str[i:(i+len(sub_str)):1]==sub_str:
        out_str=out_str+sub_str
        i = i+(len(sub_str)-1)
    else:
        out_str=out_str+'*'
    i=i+1
print(out_str)
# Out:
# *********************Peck********************

# %%
#Write a python program to find below output using loop:-

#Input:- 'This is Python class', sep = ' is', 
#Output:- ['This', 'is', 'Python class']

inp_str='This is Python class'
sep='is'
out_str=''
l_str=''
r_str=''
length=0
out_lst=[]
for letter in inp_str:
    length+=1
    out_str += letter
    if sep in out_str:
        l_str=inp_str[:length-len(sep):]
        r_str=inp_str[length::]
        out_str=''
out_lst.append(l_str)
out_lst.append(sep)
out_lst.append(r_str)
print(out_lst)
# Out:
# ['This ', 'is', ' Python class']
